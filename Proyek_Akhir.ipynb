# %% [markdown]
# Nama: Nuril Hidayati
#
# Nomor Registrasi: 1494037162100-621
#
# Pelatihan FGA DTS - Alur Machine Learning Developer
#
# Sidoarjo, Jawa Timur
#
# Dataset : https://www.kaggle.com/trolukovich/apparel-images-dataset?select=black_dress

# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle) (2022.9.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle) (7.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (3.0.4)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download trolukovich/apparel-images-dataset
# Out:
# Downloading apparel-images-dataset.zip to /content
#  99% 246M/248M [00:13<00:00, 23.2MB/s]
# 100% 248M/248M [00:13<00:00, 19.4MB/s]

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
print(tf.__version__)
# Out:
# 2.9.2

# %%
import zipfile,os
local_zip = '/content/apparel-images-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
pip install split_folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split_folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
base_dir = '/content'
splitfolders.ratio(base_dir, output = '/content/apparel-images-dataset', seed = 1314, ratio = (.8, .2))

train_dir = os.path.join('/content/apparel-images-dataset', 'train')
val_dir = os.path.join('/content/apparel-images-dataset', 'val')
# Out:
# Copying files: 11394 files [00:02, 4902.78 files/s]

# %%
black_dress_dir = os.path.join(base_dir, 'black_dress')
black_pants_dir = os.path.join(base_dir, 'black_pants')
black_shirt_dir = os.path.join(base_dir, 'black_shirt')
black_shoes_dir = os.path.join(base_dir, 'black_shoes')
black_shorts_dir = os.path.join(base_dir, 'black_shorts')
blue_dress_dir = os.path.join(base_dir, 'blue_dress')
blue_pants_dir = os.path.join(base_dir, 'blue_pants')
blue_shirt_dir = os.path.join(base_dir, 'blue_shirt')
blue_shoes_dir = os.path.join(base_dir, 'blue_shoes')
blue_shorts_dir = os.path.join(base_dir, 'blue_shorts')
brown_pants_dir = os.path.join(base_dir, 'brown_pants')
brown_shoes_dir = os.path.join(base_dir, 'brown_shoes')
brown_shorts_dir = os.path.join(base_dir, 'brown_shorts')
green_pants_dir = os.path.join(base_dir, 'green_pants')
green_shirt_dir = os.path.join(base_dir, 'green_shirt')
green_shoes_dir = os.path.join(base_dir, 'green_shoes')
green_shorts_dir = os.path.join(base_dir, 'green_shorts')
red_dress_dir = os.path.join(base_dir, 'red_dress')
red_pants_dir = os.path.join(base_dir, 'red_pants')
red_shoes_dir = os.path.join(base_dir, 'red_shoes')
white_dress_dir = os.path.join(base_dir, 'white_dress')
white_pants_dir = os.path.join(base_dir, 'white_pants')
white_shoes_dir = os.path.join(base_dir, 'white_shoes')
white_shorts_dir = os.path.join(base_dir, 'white_shorts')

# %%
train_black_dress_dir, val_black_dress_dir = train_test_split(os.listdir(black_dress_dir), test_size=0.2)
train_black_pants_dir, val_black_pants_dir = train_test_split(os.listdir(black_pants_dir), test_size=0.2)
train_black_shirt_dir, val_black_shirt_dir = train_test_split(os.listdir(black_shirt_dir), test_size=0.2)
train_black_shoes_dir, val_black_shoes_dir = train_test_split(os.listdir(black_shoes_dir), test_size=0.2)
train_black_shorts_dir, val_black_shorts_dir = train_test_split(os.listdir(black_shorts_dir), test_size=0.2)
train_blue_dress_dir, val_blue_dress_dir = train_test_split(os.listdir(blue_dress_dir), test_size=0.2)
train_blue_pants_dir, val_blue_pants_dir = train_test_split(os.listdir(blue_pants_dir), test_size=0.2)
train_blue_shirt_dir, val_blue_shirt_dir = train_test_split(os.listdir(blue_shirt_dir), test_size=0.2)
train_blue_shoes_dir, val_blue_shoes_dir = train_test_split(os.listdir(blue_shoes_dir), test_size=0.2)
train_blue_shorts_dir, val_blue_shorts_dir = train_test_split(os.listdir(blue_shorts_dir), test_size=0.2)
train_brown_pants_dir, val_brown_pants_dir = train_test_split(os.listdir(brown_pants_dir), test_size=0.2)
train_brown_shoes_dir, val_brown_shoes_dir = train_test_split(os.listdir(brown_shoes_dir), test_size=0.2)
train_brown_shorts_dir, val_brown_shorts_dir = train_test_split(os.listdir(brown_shorts_dir), test_size=0.2)
train_green_pants_dir, val_green_pants_dir = train_test_split(os.listdir(green_pants_dir), test_size=0.2)
train_green_shirt_dir, val_green_shirt_dir = train_test_split(os.listdir(green_shirt_dir), test_size=0.2)
train_green_shoes_dir, val_green_shoes_dir = train_test_split(os.listdir(green_shoes_dir), test_size=0.2)
train_green_shorts_dir, val_green_shorts_dir = train_test_split(os.listdir(green_shorts_dir), test_size=0.2)
train_red_dress_dir, val_red_dress_dir = train_test_split(os.listdir(red_dress_dir), test_size=0.2)
train_red_pants_dir, val_red_pants_dir = train_test_split(os.listdir(red_pants_dir), test_size=0.2)
train_red_shoes_dir, val_red_shoes_dir = train_test_split(os.listdir(red_shoes_dir), test_size=0.2)
train_white_dress_dir, val_white_dress_dir = train_test_split(os.listdir(white_dress_dir), test_size=0.2)
train_white_pants_dir, val_white_pants_dir = train_test_split(os.listdir(white_pants_dir), test_size=0.2)
train_white_shoes_dir, val_white_shoes_dir = train_test_split(os.listdir(white_shoes_dir), test_size=0.2)
train_white_shorts_dir, val_white_shorts_dir = train_test_split(os.listdir(white_shorts_dir), test_size=0.2)

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    validation_split=0.2,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')
 
test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    validation_split=0.2,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')
 
validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 9101 images belonging to 26 classes.
# Found 2284 images belonging to 26 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(26, activation='softmax')
])

# %%
from tensorflow.keras import optimizers
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %% [markdown]
# **Membuat Class Callback**

# %%
from tensorflow.keras.callbacks import Callback
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.92 and logs.get('val_accuracy')>0.92):
      print("\nAkurasi telah mencapai >92%! dan val akurasi telah mencapai >92%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=25,  
    epochs=100,
    callbacks=[callbacks],
    validation_data=validation_generator, 
    validation_steps=5,
)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 25s 614ms/step - loss: 2.8287 - accuracy: 0.1975 - val_loss: 1.9838 - val_accuracy: 0.4500
# Epoch 2/100
# 25/25 [==============================] - 9s 353ms/step - loss: 1.8718 - accuracy: 0.4507 - val_loss: 1.4841 - val_accuracy: 0.5500
# Epoch 3/100
# 25/25 [==============================] - 15s 588ms/step - loss: 1.3766 - accuracy: 0.5550 - val_loss: 1.1385 - val_accuracy: 0.6500
# Epoch 4/100
# 25/25 [==============================] - 17s 679ms/step - loss: 1.1536 - accuracy: 0.6425 - val_loss: 1.0264 - val_accuracy: 0.6750
# Epoch 5/100
# 25/25 [==============================] - 10s 403ms/step - loss: 1.1450 - accuracy: 0.6350 - val_loss: 1.1442 - val_accuracy: 0.6187
# Epoch 6/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.9097 - accuracy: 0.6988 - val_loss: 1.0350 - val_accuracy: 0.6938
# Epoch 7/100
# 25/25 [==============================] - 8s 325ms/step - loss: 0.8263 - accuracy: 0.7387 - val_loss: 0.7462 - val_accuracy: 0.7812
# Epoch 8/100
# 25/25 [==============================] - 8s 337ms/step - loss: 0.7677 - accuracy: 0.7516 - val_loss: 0.8759 - val_accuracy: 0.7000
# Epoch 9/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.8360 - accuracy: 0.7350 - val_loss: 0.9065 - val_accuracy: 0.7125
# Epoch 10/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.7884 - accuracy: 0.7375 - val_loss: 0.9913 - val_accuracy: 0.7250
# Epoch 11/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.7338 - accuracy: 0.7513 - val_loss: 0.7270 - val_accuracy: 0.7250
# Epoch 12/100
# 25/25 [==============================] - 8s 336ms/step - loss: 0.7060 - accuracy: 0.7663 - val_loss: 0.5770 - val_accuracy: 0.8062
# Epoch 13/100
# 25/25 [==============================] - 9s 347ms/step - loss: 0.6489 - accuracy: 0.7937 - val_loss: 0.7112 - val_accuracy: 0.8125
# Epoch 14/100
# 25/25 [==============================] - 9s 358ms/step - loss: 0.6378 - accuracy: 0.7975 - val_loss: 0.7668 - val_accuracy: 0.7563
# Epoch 15/100
# 25/25 [==============================] - 9s 321ms/step - loss: 0.6091 - accuracy: 0.8175 - val_loss: 0.6709 - val_accuracy: 0.8125
# Epoch 16/100
# 25/25 [==============================] - 8s 327ms/step - loss: 0.5935 - accuracy: 0.8087 - val_loss: 0.5291 - val_accuracy: 0.8813
# Epoch 17/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.5623 - accuracy: 0.8275 - val_loss: 0.8093 - val_accuracy: 0.7750
# Epoch 18/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.6053 - accuracy: 0.8037 - val_loss: 0.7322 - val_accuracy: 0.7750
# Epoch 19/100
# 25/25 [==============================] - 8s 325ms/step - loss: 0.4874 - accuracy: 0.8288 - val_loss: 0.7909 - val_accuracy: 0.7688
# Epoch 20/100
# 25/25 [==============================] - 9s 362ms/step - loss: 0.5123 - accuracy: 0.8325 - val_loss: 0.4231 - val_accuracy: 0.8938
# Epoch 21/100
# 25/25 [==============================] - 8s 310ms/step - loss: 0.5793 - accuracy: 0.8131 - val_loss: 0.4444 - val_accuracy: 0.8813
# Epoch 22/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.5619 - accuracy: 0.8156 - val_loss: 0.6251 - val_accuracy: 0.7875
# Epoch 23/100
# 25/25 [==============================] - 8s 318ms/step - loss: 0.5287 - accuracy: 0.8313 - val_loss: 0.6539 - val_accuracy: 0.7750
# Epoch 24/100
# 25/25 [==============================] - 9s 358ms/step - loss: 0.5183 - accuracy: 0.8438 - val_loss: 0.4653 - val_accuracy: 0.8687
# Epoch 25/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.4707 - accuracy: 0.8550 - val_loss: 0.4592 - val_accuracy: 0.8750
# Epoch 26/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.4450 - accuracy: 0.8562 - val_loss: 0.6007 - val_accuracy: 0.8438
# Epoch 27/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.4479 - accuracy: 0.8600 - val_loss: 0.4766 - val_accuracy: 0.9000
# Epoch 28/100
# 25/25 [==============================] - 8s 312ms/step - loss: 0.4262 - accuracy: 0.8681 - val_loss: 0.4303 - val_accuracy: 0.8687
# Epoch 29/100
# 25/25 [==============================] - 9s 365ms/step - loss: 0.4546 - accuracy: 0.8625 - val_loss: 0.4525 - val_accuracy: 0.8750
# Epoch 30/100
# 25/25 [==============================] - 8s 326ms/step - loss: 0.4664 - accuracy: 0.8487 - val_loss: 0.6631 - val_accuracy: 0.8000
# Epoch 31/100
# 25/25 [==============================] - 9s 363ms/step - loss: 0.5184 - accuracy: 0.8300 - val_loss: 0.5304 - val_accuracy: 0.8313
# Epoch 32/100
# 25/25 [==============================] - 8s 330ms/step - loss: 0.4177 - accuracy: 0.8700 - val_loss: 0.5694 - val_accuracy: 0.8562
# Epoch 33/100
# 25/25 [==============================] - 9s 345ms/step - loss: 0.3549 - accuracy: 0.8875 - val_loss: 0.7270 - val_accuracy: 0.7750
# Epoch 34/100
# 25/25 [==============================] - 9s 356ms/step - loss: 0.3926 - accuracy: 0.8813 - val_loss: 0.4406 - val_accuracy: 0.8625
# Epoch 35/100
# 25/25 [==============================] - 10s 399ms/step - loss: 0.4171 - accuracy: 0.8600 - val_loss: 0.5529 - val_accuracy: 0.8438
# Epoch 36/100
# 25/25 [==============================] - 8s 316ms/step - loss: 0.4195 - accuracy: 0.8637 - val_loss: 0.5232 - val_accuracy: 0.8313
# Epoch 37/100
# 25/25 [==============================] - 9s 361ms/step - loss: 0.3770 - accuracy: 0.8850 - val_loss: 0.6984 - val_accuracy: 0.8313
# Epoch 38/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.4802 - accuracy: 0.8462 - val_loss: 0.4705 - val_accuracy: 0.8500
# Epoch 39/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.3023 - accuracy: 0.9125 - val_loss: 0.5789 - val_accuracy: 0.8313
# Epoch 40/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.4400 - accuracy: 0.8725 - val_loss: 0.5136 - val_accuracy: 0.8750
# Epoch 41/100
# 25/25 [==============================] - 8s 321ms/step - loss: 0.4061 - accuracy: 0.8763 - val_loss: 0.6860 - val_accuracy: 0.8125
# Epoch 42/100
# 25/25 [==============================] - 8s 327ms/step - loss: 0.4122 - accuracy: 0.8712 - val_loss: 0.3469 - val_accuracy: 0.8938
# Epoch 43/100
# 25/25 [==============================] - 8s 320ms/step - loss: 0.3962 - accuracy: 0.8784 - val_loss: 0.4321 - val_accuracy: 0.8562
# Epoch 44/100
# 25/25 [==============================] - 8s 330ms/step - loss: 0.3240 - accuracy: 0.8975 - val_loss: 0.5027 - val_accuracy: 0.9000
# Epoch 45/100
# 25/25 [==============================] - 8s 334ms/step - loss: 0.3226 - accuracy: 0.9001 - val_loss: 0.4636 - val_accuracy: 0.8687
# Epoch 46/100
# 25/25 [==============================] - 8s 332ms/step - loss: 0.3563 - accuracy: 0.8875 - val_loss: 0.3725 - val_accuracy: 0.8750
# Epoch 47/100
# 25/25 [==============================] - 8s 326ms/step - loss: 0.3183 - accuracy: 0.8963 - val_loss: 0.5964 - val_accuracy: 0.8375
# Epoch 48/100
# 25/25 [==============================] - 8s 331ms/step - loss: 0.3574 - accuracy: 0.8925 - val_loss: 0.4208 - val_accuracy: 0.8875
# Epoch 49/100
# 25/25 [==============================] - 8s 329ms/step - loss: 0.2856 - accuracy: 0.9162 - val_loss: 0.5504 - val_accuracy: 0.8625
# Epoch 50/100
# 25/25 [==============================] - 9s 360ms/step - loss: 0.3375 - accuracy: 0.8925 - val_loss: 0.4749 - val_accuracy: 0.8562
# Epoch 51/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.3215 - accuracy: 0.9125 - val_loss: 0.2429 - val_accuracy: 0.9125
# Epoch 52/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.3102 - accuracy: 0.9075 - val_loss: 0.3861 - val_accuracy: 0.8813
# Epoch 53/100
# 25/25 [==============================] - 8s 328ms/step - loss: 0.3349 - accuracy: 0.8863 - val_loss: 0.4433 - val_accuracy: 0.8687
# Epoch 54/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.3315 - accuracy: 0.8875 - val_loss: 0.3922 - val_accuracy: 0.8750
# Epoch 55/100
# 25/25 [==============================] - 9s 360ms/step - loss: 0.2826 - accuracy: 0.9050 - val_loss: 0.4167 - val_accuracy: 0.9000
# Epoch 56/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.2812 - accuracy: 0.9038 - val_loss: 0.4411 - val_accuracy: 0.8438
# Epoch 57/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.2387 - accuracy: 0.9137 - val_loss: 0.3394 - val_accuracy: 0.9062
# Epoch 58/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.2870 - accuracy: 0.9125 - val_loss: 0.5405 - val_accuracy: 0.8250
# Epoch 59/100
# 25/25 [==============================] - 9s 361ms/step - loss: 0.2565 - accuracy: 0.9237 - val_loss: 0.2431 - val_accuracy: 0.8938
# Epoch 60/100
# 25/25 [==============================] - 8s 321ms/step - loss: 0.2516 - accuracy: 0.9112 - val_loss: 0.3774 - val_accuracy: 0.8750
# Epoch 61/100
# 25/25 [==============================] - 9s 360ms/step - loss: 0.2622 - accuracy: 0.9187 - val_loss: 0.4646 - val_accuracy: 0.8750
# Epoch 62/100
# 25/25 [==============================] - 9s 362ms/step - loss: 0.3119 - accuracy: 0.8963 - val_loss: 0.3573 - val_accuracy: 0.8813
# Epoch 63/100
# 25/25 [==============================] - 8s 316ms/step - loss: 0.2498 - accuracy: 0.9162 - val_loss: 0.6265 - val_accuracy: 0.8500
# Epoch 64/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.2744 - accuracy: 0.9125 - val_loss: 0.6956 - val_accuracy: 0.8250
# Epoch 65/100
# 25/25 [==============================] - 9s 363ms/step - loss: 0.2565 - accuracy: 0.9162 - val_loss: 0.4771 - val_accuracy: 0.8813
# Epoch 66/100
# 25/25 [==============================] - 9s 339ms/step - loss: 0.2852 - accuracy: 0.9137 - val_loss: 0.4491 - val_accuracy: 0.8938
# Epoch 67/100
# 25/25 [==============================] - 8s 319ms/step - loss: 0.2946 - accuracy: 0.9112 - val_loss: 0.4881 - val_accuracy: 0.8813
# Epoch 68/100
# 25/25 [==============================] - 8s 326ms/step - loss: 0.3285 - accuracy: 0.8963 - val_loss: 0.5375 - val_accuracy: 0.8250
# Epoch 69/100
# 25/25 [==============================] - 9s 359ms/step - loss: 0.3088 - accuracy: 0.8975 - val_loss: 0.4125 - val_accuracy: 0.8875
# Epoch 70/100
# 25/25 [==============================] - 9s 364ms/step - loss: 0.2602 - accuracy: 0.9137 - val_loss: 0.3269 - val_accuracy: 0.9125
# Epoch 71/100
# 25/25 [==============================] - 10s 400ms/step - loss: 0.2271 - accuracy: 0.9325 - val_loss: 0.2644 - val_accuracy: 0.9062
# Epoch 72/100
# 25/25 [==============================] - 9s 361ms/step - loss: 0.2097 - accuracy: 0.9413 - val_loss: 0.2371 - val_accuracy: 0.9125
# Epoch 73/100
# 25/25 [==============================] - 8s 321ms/step - loss: 0.2329 - accuracy: 0.9200 - val_loss: 0.5577 - val_accuracy: 0.8500
# Epoch 74/100
# 25/25 [==============================] - 8s 320ms/step - loss: 0.2678 - accuracy: 0.9137 - val_loss: 0.2758 - val_accuracy: 0.9312
# Epoch 75/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.2047 - accuracy: 0.9337 - val_loss: 0.4760 - val_accuracy: 0.8625
# Epoch 76/100
# 25/25 [==============================] - 9s 365ms/step - loss: 0.2019 - accuracy: 0.9250 - val_loss: 0.3216 - val_accuracy: 0.8875
# Epoch 77/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.2565 - accuracy: 0.9150 - val_loss: 0.4563 - val_accuracy: 0.8813
# Epoch 78/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.2392 - accuracy: 0.9187 - val_loss: 0.5638 - val_accuracy: 0.8562
# Epoch 79/100
# 25/25 [==============================] - 9s 361ms/step - loss: 0.2398 - accuracy: 0.9250 - val_loss: 0.5195 - val_accuracy: 0.8562
# Epoch 80/100
# 25/25 [==============================] - 8s 319ms/step - loss: 0.2308 - accuracy: 0.9250 - val_loss: 0.3466 - val_accuracy: 0.8938
# Epoch 81/100
# 25/25 [==============================] - 8s 325ms/step - loss: 0.2480 - accuracy: 0.9112 - val_loss: 0.3941 - val_accuracy: 0.9062
# Epoch 82/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.2110 - accuracy: 0.9225 - val_loss: 0.7102 - val_accuracy: 0.8250
# Epoch 83/100
# 25/25 [==============================] - 9s 363ms/step - loss: 0.2925 - accuracy: 0.9050 - val_loss: 0.3787 - val_accuracy: 0.9187
# Epoch 84/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.2344 - accuracy: 0.9300 - val_loss: 0.4502 - val_accuracy: 0.8687
# Epoch 85/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.2023 - accuracy: 0.9400 - val_loss: 0.3699 - val_accuracy: 0.9062
# Epoch 86/100
# 25/25 [==============================] - 8s 326ms/step - loss: 0.2521 - accuracy: 0.9200 - val_loss: 0.3349 - val_accuracy: 0.8938
# Epoch 87/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9362
# Akurasi telah mencapai >92%! dan val akurasi telah mencapai >92%!
# 25/25 [==============================] - 8s 326ms/step - loss: 0.1912 - accuracy: 0.9362 - val_loss: 0.2552 - val_accuracy: 0.9312

# %%
model.evaluate(validation_generator)
# Out:
# 72/72 [==============================] - 19s 260ms/step - loss: 0.4168 - accuracy: 0.8901
# [0.41684654355049133, 0.8901050686836243]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training Accuracy and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training Loss and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(loss, label='Training Loss')
plt.legend(loc='lower right')
plt.ylabel('Training')
plt.ylim([min(plt.ylim()),1])
plt.title('Training Accuracy and Training Loss')

plt.subplot(2, 1, 2)
plt.plot(val_acc, label='Validation Accuracy')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Validation Accuracy and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Konversi model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %%
with tf.io.gfile.GFile('model.tflite', 'wb') as f:
  f.write(tflite_model)
